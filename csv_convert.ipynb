# %%
import pandas as pd 

df_april=pd.read_excel("/Users/mmsurya/Desktop/ai_cb_csv/Data/Bidwell April 2024.xlsx")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_may=pd.read_excel("/Users/mmsurya/Desktop/Chatbot/Data/Bidwell May 2024.xlsx")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_april.to_csv('Bidwell April 2024.csv', index=False)

# %%
df_may.to_csv('Bidwell May 2024.csv', index=False)
